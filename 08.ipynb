# %% [markdown]
# # MFCC 전처리 과정을 통한 Audio MNIST 분류 학습
#
# ---

# %% [markdown]
# ## Import

# %%
# cuda gpu 설정 코드
import os
os.add_dll_directory('C:\\Program Files\\NVIDIA GPU Computing Toolkit\\CUDA\\v11.2\\bin')
os.environ["CUDA_VISIBLE_DEVICES"]="0"
# cuda=11.2 cudnn=8.1.0 python=3.8 tensorflow-gpu=2.10.0
# !!!!! 오류 발생 시, 위 코드 삭제 후 실행 !!!!! ##

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import pandas as pd
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split

import joblib
import glob
import librosa
from IPython.display import Audio
import IPython.display as ipd

# %% [markdown]
# Audio Mnist : <br>
# https://www.kaggle.com/datasets/alanchn31/free-spoken-digits

# %% [markdown]
# ## Load Data

# %%
#dir = '/data/free-spoken-digit-dataset-master/recordings/'
dir = 'C:/Users/sihyu/OneDrive - Kumoh/Source_File/VScode/python/DeepLearning/hw08/data/free-spoken-digit-dataset-master/recordings/'
files = sorted(glob.glob(dir + '/*.wav', recursive=True))

print(len(files))
print(files[0])

label = files[0].split('/')[-1].split('_')[0][-1]
print(label)
# Out:
# 3000
# C:/Users/sihyu/OneDrive - Kumoh/Source_File/VScode/python/DeepLearning/hw08/data/free-spoken-digit-dataset-master/recordings\0_george_0.wav
# 0

# %% [markdown]
# ## 데이터 특성 확인

# %%
def wav_info(file):
    data, sr = librosa.load(file)
    print(f"data length: {len(data)}, sampling rate: {sr}")
    ipd.display(ipd.Audio(data, rate=sr))

    fig,ax = plt.subplots(1,3,figsize=(12,3))
    ax[0].plot(data)
    ax[0].set_title(f"{file.split('/')[-1]}, sr={sr}")

    mel = librosa.feature.melspectrogram(y=data, sr=sr)
    librosa.display.specshow(mel, x_axis='time', y_axis='mel', ax=ax[1])
    ax[1].set_title(f"{mel.shape}")

    mfcc = librosa.feature.mfcc(y=data, sr=sr)
    librosa.display.specshow(mfcc, x_axis='time', ax=ax[2])
    ax[2].set_title(f"{mfcc.shape}")
    plt.tight_layout()
    plt.show()

num = np.random.randint(0,3000,3)
for file in np.array(files)[num]:
    wav_info(file)
# Out:
# data length: 8956, sampling rate: 22050
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# data length: 7434, sampling rate: 22050
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# data length: 5273, sampling rate: 22050
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## dataframe 생성 및 Trim(오디오 길이 맞춤)

# %%
def trim(file):
    dataset = []
    data, sr = librosa.load(file)

    data, _ = librosa.effects.trim(data, top_db=10) #top_db: 임계값(데시벨)
    data = librosa.util.fix_length(data, size=10000) #10000으로 길이 맞추기

    mel = librosa.feature.melspectrogram(y=data, sr=sr)
    mfcc = librosa.feature.mfcc(y=data, sr=sr)
    label = file.split('/')[-1].split('_')[0][-1]
    dataset.append([mel, mfcc, label])

    return dataset

dataset = joblib.Parallel(n_jobs=-1)(joblib.delayed(trim)(file) for file in files)
df = pd.DataFrame(np.array(dataset, dtype=object).squeeze(), columns=['mel','mfcc','label'])

x_mel = np.array(df['mel'].tolist())
x_mfcc = np.array(df['mfcc'].tolist())
y = np.array(df['label'].tolist())
y = y.astype(int)
print(y)

print(x_mel.shape, x_mfcc.shape, y.shape)
# Out:
# [0 0 0 ... 9 9 9]
# (3000, 128, 20) (3000, 20, 20) (3000,)

# %% [markdown]
# ## train test split

# %%
x_train, x_test, y_train, y_test = train_test_split(x_mfcc, y, test_size=0.2, stratify=y, shuffle=True, random_state=2023)
print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)
print(x_train[0].shape)
print(y_train)
# Out:
# (2400, 20, 20) (600, 20, 20) (2400,) (600,)
# (20, 20)
# [1 1 8 ... 4 2 0]

# %% [markdown]
# ## Model 정의

# %%
inputs = keras.Input(shape=(20, 20))
x = layers.Conv1D(32, 3, activation='relu')(inputs)
x = layers.MaxPooling1D(2)(x)
x = layers.Conv1D(64, 3, activation='relu')(x)
x = layers.MaxPooling1D(2)(x)
x = layers.Flatten()(x)
x = layers.Dense(128, activation='relu')(x)
outputs = layers.Dense(10, activation='softmax')(x)
model = keras.Model(inputs=inputs, outputs=outputs)

model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 20, 20)]          0
#
#  conv1d_4 (Conv1D)           (None, 18, 32)            1952
#
#  max_pooling1d_4 (MaxPooling  (None, 9, 32)            0
#  1D)
#
#  conv1d_5 (Conv1D)           (None, 7, 64)             6208
#
#  max_pooling1d_5 (MaxPooling  (None, 3, 64)            0
#  1D)
#
#  flatten_2 (Flatten)         (None, 192)               0
#
#  dense_4 (Dense)             (None, 128)               24704
#
#  dense_5 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 34,154
# Trainable params: 34,154
# Non-trainable params: 0
# _________________________________________________________________

# %%
#checkpoint = keras.callbacks.ModelCheckpoint(filepath='model/hw08.hdf5', monitor='loss', save_best_only=True, verbose=0)
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=50, batch_size=16)
# Out:
# Epoch 1/50
# 150/150 [==============================] - 1s 6ms/step - loss: 3.9672 - accuracy: 0.6092 - val_loss: 0.5668 - val_accuracy: 0.8333
# Epoch 2/50
# 150/150 [==============================] - 1s 4ms/step - loss: 0.4552 - accuracy: 0.8763 - val_loss: 0.3139 - val_accuracy: 0.9050
# Epoch 3/50
# 150/150 [==============================] - 1s 4ms/step - loss: 0.2608 - accuracy: 0.9221 - val_loss: 0.3464 - val_accuracy: 0.9083
# Epoch 4/50
# 150/150 [==============================] - 1s 4ms/step - loss: 0.1873 - accuracy: 0.9396 - val_loss: 0.2806 - val_accuracy: 0.9200
# Epoch 5/50
# 150/150 [==============================] - 1s 4ms/step - loss: 0.1323 - accuracy: 0.9583 - val_loss: 0.2003 - val_accuracy: 0.9433
# Epoch 6/50
# 150/150 [==============================] - 1s 4ms/step - loss: 0.0928 - accuracy: 0.9712 - val_loss: 0.2632 - val_accuracy: 0.9233
# Epoch 7/50
# 150/150 [==============================] - 1s 4ms/step - loss: 0.1162 - accuracy: 0.9583 - val_loss: 0.2179 - val_accuracy: 0.9300
# Epoch 8/50
# 150/150 [==============================] - 1s 4ms/step - loss: 0.0830 - accuracy: 0.9742 - val_loss: 0.1934 - val_accuracy: 0.9517
# Epoch 9/50
# 150/150 [==============================] - 1s 4ms/step - loss: 0.0571 - accuracy: 0.9817 - val_loss: 0.1766 - val_accuracy: 0.9583
# Epoch 10/50
# 150/150 [==============================] - 1s 4ms/step - loss: 0.0266 - accuracy: 0.9929 - val_loss: 0.1652 - val_accuracy: 0.9633
# Epoch 11/50
# 150/150 [==============================] - 1s 4ms/step - loss: 0.0364 - accuracy: 0.9887 - val_loss: 0.1668 - val_accuracy: 0.9567
# Epoch 12/50
# 150/150 [==============================] - 1s 4ms/step - loss: 0.0761 - accuracy: 0.9783 - val_loss: 0.4547 - val_accuracy: 0.9100
# Epoch 13/50
# 150/150 [==============================] - 1s 4ms/step - loss: 0.1262 - accuracy: 0.9654 - val_loss: 0.2079 - val_accuracy: 0.9450
# Epoch 14/50
# 150/150 [==============================] - 1s 4ms/step - loss: 0.1095 - accuracy: 0.9729 - val_loss: 0.2253 - val_accuracy: 0.9467
# Epoch 15/50
# 150/150 [==============================] - 1s 4ms/step - loss: 0.0484 - accuracy: 0.9850 - val_loss: 0.1838 - val_accuracy: 0.9517
# Epoch 16/50
# 150/150 [==============================] - 1s 4ms/step - loss: 0.0584 - accuracy: 0.9829 - val_loss: 0.1339 - val_accuracy: 0.9683
# Epoch 17/50
# 150/150 [==============================] - 1s 4ms/step - loss: 0.0340 - accuracy: 0.9900 - val_loss: 0.2054 - val_accuracy: 0.9633
# Epoch 18/50
# 150/150 [==============================] - 1s 4ms/step - loss: 0.0172 - accuracy: 0.9942 - val_loss: 0.1375 - val_accuracy: 0.9633
# Epoch 19/50
# 150/150 [==============================] - 1s 4ms/step - loss: 0.0090 - accuracy: 0.9975 - val_loss: 0.1521 - val_accuracy: 0.9750
# Epoch 20/50
# 150/150 [==============================] - 1s 4ms/step - loss: 0.0727 - accuracy: 0.9796 - val_loss: 0.3194 - val_accuracy: 0.9417
# Epoch 21/50
# 150/150 [==============================] - 1s 4ms/step - loss: 0.0985 - accuracy: 0.9700 - val_loss: 0.3260 - val_accuracy: 0.9467
# Epoch 22/50
# 150/150 [==============================] - 1s 4ms/step - loss: 0.0593 - accuracy: 0.9821 - val_loss: 0.2520 - val_accuracy: 0.9450
# Epoch 23/50
# 150/150 [==============================] - 1s 4ms/step - loss: 0.1072 - accuracy: 0.9754 - val_loss: 0.2483 - val_accuracy: 0.9467
# Epoch 24/50
# 150/150 [==============================] - 1s 4ms/step - loss: 0.0515 - accuracy: 0.9875 - val_loss: 0.3043 - val_accuracy: 0.9550
# Epoch 25/50
# 150/150 [==============================] - 1s 4ms/step - loss: 0.0412 - accuracy: 0.9879 - val_loss: 0.2163 - val_accuracy: 0.9650
# Epoch 26/50
# 150/150 [==============================] - 1s 4ms/step - loss: 0.0170 - accuracy: 0.9942 - val_loss: 0.1254 - val_accuracy: 0.9750
# Epoch 27/50
# 150/150 [==============================] - 1s 4ms/step - loss: 0.0065 - accuracy: 0.9979 - val_loss: 0.1664 - val_accuracy: 0.9650
# Epoch 28/50
# 150/150 [==============================] - 1s 4ms/step - loss: 0.0185 - accuracy: 0.9962 - val_loss: 0.1703 - val_accuracy: 0.9717
# Epoch 29/50
# 150/150 [==============================] - 1s 4ms/step - loss: 0.0286 - accuracy: 0.9908 - val_loss: 0.3318 - val_accuracy: 0.9400
# Epoch 30/50
# 150/150 [==============================] - 1s 4ms/step - loss: 0.0522 - accuracy: 0.9812 - val_loss: 0.1427 - val_accuracy: 0.9717
# Epoch 31/50
# 150/150 [==============================] - 1s 4ms/step - loss: 0.0431 - accuracy: 0.9862 - val_loss: 0.2872 - val_accuracy: 0.9567
# Epoch 32/50
# 150/150 [==============================] - 1s 4ms/step - loss: 0.0702 - accuracy: 0.9779 - val_loss: 0.2294 - val_accuracy: 0.9683
# Epoch 33/50
# 150/150 [==============================] - 1s 4ms/step - loss: 0.0539 - accuracy: 0.9846 - val_loss: 0.1746 - val_accuracy: 0.9650
# Epoch 34/50
# 150/150 [==============================] - 1s 4ms/step - loss: 0.0552 - accuracy: 0.9842 - val_loss: 0.2665 - val_accuracy: 0.9600
# Epoch 35/50
# 150/150 [==============================] - 1s 4ms/step - loss: 0.0163 - accuracy: 0.9962 - val_loss: 0.2510 - val_accuracy: 0.9700
# Epoch 36/50
# 150/150 [==============================] - 1s 4ms/step - loss: 0.0455 - accuracy: 0.9900 - val_loss: 0.2364 - val_accuracy: 0.9667
# Epoch 37/50
# 150/150 [==============================] - 1s 4ms/step - loss: 0.0093 - accuracy: 0.9967 - val_loss: 0.1673 - val_accuracy: 0.9683
# Epoch 38/50
# 150/150 [==============================] - 1s 4ms/step - loss: 0.0053 - accuracy: 0.9979 - val_loss: 0.1770 - val_accuracy: 0.9667
# Epoch 39/50
# 150/150 [==============================] - 1s 4ms/step - loss: 0.0162 - accuracy: 0.9954 - val_loss: 0.2013 - val_accuracy: 0.9683
# Epoch 40/50
# 150/150 [==============================] - 1s 4ms/step - loss: 0.0097 - accuracy: 0.9975 - val_loss: 0.3114 - val_accuracy: 0.9633
# Epoch 41/50
# 150/150 [==============================] - 1s 4ms/step - loss: 0.0082 - accuracy: 0.9967 - val_loss: 0.1776 - val_accuracy: 0.9717
# Epoch 42/50
# 150/150 [==============================] - 1s 4ms/step - loss: 0.0039 - accuracy: 0.9996 - val_loss: 0.1612 - val_accuracy: 0.9767
# Epoch 43/50
# 150/150 [==============================] - 1s 4ms/step - loss: 3.7969e-04 - accuracy: 1.0000 - val_loss: 0.1794 - val_accuracy: 0.9717
# Epoch 44/50
# 150/150 [==============================] - 1s 4ms/step - loss: 0.0015 - accuracy: 0.9996 - val_loss: 0.1921 - val_accuracy: 0.9683
# Epoch 45/50
# 150/150 [==============================] - 1s 4ms/step - loss: 0.0058 - accuracy: 0.9987 - val_loss: 0.2217 - val_accuracy: 0.9667
# Epoch 46/50
# 150/150 [==============================] - 1s 4ms/step - loss: 0.0118 - accuracy: 0.9971 - val_loss: 0.1714 - val_accuracy: 0.9750
# Epoch 47/50
# 150/150 [==============================] - 1s 4ms/step - loss: 0.0791 - accuracy: 0.9817 - val_loss: 0.8602 - val_accuracy: 0.9033
# Epoch 48/50
# 150/150 [==============================] - 1s 4ms/step - loss: 0.2331 - accuracy: 0.9496 - val_loss: 0.4103 - val_accuracy: 0.9533
# Epoch 49/50
# 150/150 [==============================] - 1s 4ms/step - loss: 0.0704 - accuracy: 0.9812 - val_loss: 0.2815 - val_accuracy: 0.9600
# Epoch 50/50
# 150/150 [==============================] - 1s 4ms/step - loss: 0.0168 - accuracy: 0.9954 - val_loss: 0.4031 - val_accuracy: 0.9583

# %%
print(min(history.history["loss"]))
print(max(history.history["accuracy"]))
print(min(history.history["val_loss"]))
print(max(history.history["val_accuracy"]))
# Out:
# 0.00037968624383211136
# 1.0
# 0.12540264427661896
# 0.9766666889190674

# %%
df_result = pd.DataFrame(history.history)
sns.lineplot(df_result[["loss", "val_loss"]])
plt.xlabel("epoch")
plt.show()

# %%
sns.lineplot(df_result[["accuracy", "val_accuracy"]])
plt.xlabel("epoch")
plt.show()
